# %%
# Explore information returned about an article.
import requests
import json

# Make an API call, and store the response.
url = 'https://hacker-news.firebaseio.com/v0/item/19155826.json'
r = requests.get(url)
print(f"Status code: {r.status_code}")

# Explore the structure of the data.
response_dict = r.json()
readable_file = 'data/readable_hn_data.json'
with open(readable_file, 'w') as f:
    json.dump(response_dict, f, indent=4)
# Out:
# Status code: 200

# %%
# Top stories on HackerNews
from operator import itemgetter
import requests

url = 'https://hacker-news.firebaseio.com/v0/topstories.json'
r = requests.get(url)
print(f"Status code: {r.status_code}")

# Process information about each submission.
submission_ids = r.json()
submission_dicts = []
for submission_id in submission_ids[ : 30]:
    # Make a separate API call for each submission.
    url = f"https://hacker-news.firebaseio.com/v0/item/{submission_id}.json"
    r = requests.get(url)
    #print(f"id: {submission_id}\tstatus:{r.status_code}")
    response_dict = r.json()

    # Build a dictionary for each article.
    submission_dict = {
        'title': response_dict['title'],
        'hn_link': f"https://news.ycombinator.com/item?id={submission_id}",
        'comments': response_dict.get('descendants', 0)
    }
    submission_dicts.append(submission_dict)

submission_dicts = sorted(submission_dicts, key=itemgetter('comments'), reverse=True)

for submission_dict in submission_dicts:
    print(f"\nTitle: {submission_dict['title']}")
    print(f"Discussion link: {submission_dict['hn_link']}")
    print(f"Comments: {submission_dict['comments']}")
# Out:
# Status code: 200
# id: 39597030	status:200
# id: 39597131	status:200
# id: 39598903	status:200
# id: 39597184	status:200
# id: 39597525	status:200
# id: 39592444	status:200
# id: 39597847	status:200
# id: 39598189	status:200
# id: 39598826	status:200
# id: 39599150	status:200
# id: 39579465	status:200
# id: 39578832	status:200
# id: 39591772	status:200
# id: 39598170	status:200
# id: 39590666	status:200
# id: 39572164	status:200
# id: 39592280	status:200
# id: 39580219	status:200
# id: 39592499	status:200
# id: 39599051	status:200
# id: 39592771	status:200
# id: 39591972	status:200
# id: 39591529	status:200
# id: 39581398	status:200
# id: 39591115	status:200
# id: 39593256	status:200
# id: 39590683	status:200
# id: 39571406	status:200
# id: 39587763	status:200
# id: 39594541	status:200
#
# Title: Claude 3 model family
# Discussion link: https://news.ycombinator.com/item?id=39590666
# Comments: 560
#
# Title: Why it's so challenging to land upright on the moon
# Discussion link: https://news.ycombinator.com/item?id=39591772
# Comments: 216
#
# Title: The hunt for the missing data type
# Discussion link: https://news.ycombinator.com/item?id=39592444
# Comments: 183
#
# Title: Show HN: 3 years and 1M users later, I just open-sourced my "Internet OS"
# Discussion link: https://news.ycombinator.com/item?id=39597030
# Comments: 133
#
# Title: European crash tester says carmakers must bring back physical controls
# Discussion link: https://news.ycombinator.com/item?id=39598189
# Comments: 130
#
# Title: What flying was like fifty years ago
# Discussion link: https://news.ycombinator.com/item?id=39591115
# Comments: 105
#
# Title: Scientists put Jared Diamond's continental axis hypothesis to the test
