# %%
# Get the Sitka, Alaska sample data and put in the ./data directory
! wget -nc https://raw.githubusercontent.com/ehmatthes/pcc_2e/master/chapter_16/the_csv_file_format/data/sitka_weather_2018_simple.csv -P ./data
# Out:
# --2024-03-03 01:16:59--  https://raw.githubusercontent.com/ehmatthes/pcc_2e/master/chapter_16/the_csv_file_format/data/sitka_weather_2018_simple.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24735 (24K) [text/plain]
# Saving to: ‘./data/sitka_weather_2018_simple.csv’
#
# sitka_weather_2018_ 100%[===================>]  24.16K  --.-KB/s    in 0.003s
#
# 2024-03-03 01:16:59 (8.79 MB/s) - ‘./data/sitka_weather_2018_simple.csv’ saved [24735/24735]

# %%
# Parsing the CSV file headers
import csv

filename = "data/sitka_weather_2018_simple.csv"
with open(filename) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    print(header_row)
# Out:
# ['{"payload":{"allShortcutsEnabled":false', 'fileTree:{"chapter_16/the_csv_file_format/data":{"items":[{"name":"death_valley_2018_full.csv"', 'path:"chapter_16/the_csv_file_format/data/death_valley_2018_full.csv"', 'contentType:"file"}', '{"name":"death_valley_2018_simple.csv"', 'path:"chapter_16/the_csv_file_format/data/death_valley_2018_simple.csv"', 'contentType:"file"}', '{"name":"sitka_weather_07-2018_simple.csv"', 'path:"chapter_16/the_csv_file_format/data/sitka_weather_07-2018_simple.csv"', 'contentType:"file"}', '{"name":"sitka_weather_2018_full.csv"', 'path:"chapter_16/the_csv_file_format/data/sitka_weather_2018_full.csv"', 'contentType:"file"}', '{"name":"sitka_weather_2018_simple.csv"', 'path:"chapter_16/the_csv_file_format/data/sitka_weather_2018_simple.csv"', 'contentType:"file"}]', 'totalCount:5}', 'chapter_16/the_csv_file_format:{"items":[{"name":"data"', 'path:"chapter_16/the_csv_file_format/data"', 'contentType:"directory"}', '{"name":"revisions_printing_4"', 'path:"chapter_16/the_csv_file_format/revisions_printing_4"', 'contentType:"directory"}', '{"name":"death_valley_highs_lows.py"', 'path:"chapter_16/the_csv_file_format/death_valley_highs_lows.py"', 'contentType:"file"}', '{"name":"sitka_highs.py"', 'path:"chapter_16/the_csv_file_format/sitka_highs.py"', 'contentType:"file"}', '{"name":"sitka_highs_lows.py"', 'path:"chapter_16/the_csv_file_format/sitka_highs_lows.py"', 'contentType:"file"}]', 'totalCount:5}', 'chapter_16:{"items":[{"name":"mapping_global_data_sets"', 'path:"chapter_16/mapping_global_data_sets"', 'contentType:"directory"}', '{"name":"the_csv_file_format"', 'path:"chapter_16/the_csv_file_format"', 'contentType:"directory"}]', 'totalCount:2}', ':{"items":[{"name":"beyond_pcc"', 'path:"beyond_pcc"', 'contentType:"directory"}', '{"name":"chapter_01"', 'path:"chapter_01"', 'contentType:"directory"}', '{"name":"chapter_02"', 'path:"chapter_02"', 'contentType:"directory"}', '{"name":"chapter_03"', 'path:"chapter_03"', 'contentType:"directory"}', '{"name":"chapter_04"', 'path:"chapter_04"', 'contentType:"directory"}', '{"name":"chapter_05"', 'path:"chapter_05"', 'contentType:"directory"}', '{"name":"chapter_06"', 'path:"chapter_06"', 'contentType:"directory"}', '{"name":"chapter_07"', 'path:"chapter_07"', 'contentType:"directory"}', '{"name":"chapter_08"', 'path:"chapter_08"', 'contentType:"directory"}', '{"name":"chapter_09"', 'path:"chapter_09"', 'contentType:"directory"}', '{"name":"chapter_10"', 'path:"chapter_10"', 'contentType:"directory"}', '{"name":"chapter_11"', 'path:"chapter_11"', 'contentType:"directory"}', '{"name":"chapter_12"', 'path:"chapter_12"', 'contentType:"directory"}', '{"name":"chapter_13"', 'path:"chapter_13"', 'contentType:"directory"}', '{"name":"chapter_14"', 'path:"chapter_14"', 'contentType:"directory"}', '{"name":"chapter_15"', 'path:"chapter_15"', 'contentType:"directory"}', '{"name":"chapter_16"', 'path:"chapter_16"', 'contentType:"directory"}', '{"name":"chapter_17"', 'path:"chapter_17"', 'contentType:"directory"}', '{"name":"chapter_18"', 'path:"chapter_18"', 'contentType:"directory"}', '{"name":"chapter_19"', 'path:"chapter_19"', 'contentType:"directory"}', '{"name":"chapter_20"', 'path:"chapter_20"', 'contentType:"directory"}', '{"name":"cheat_sheets"', 'path:"cheat_sheets"', 'contentType:"directory"}', '{"name":".gitignore"', 'path:".gitignore"', 'contentType:"file"}', '{"name":"README.md"', 'path:"README.md"', 'contentType:"file"}]', 'totalCount:24}}', 'fileTreeProcessingTime:7.503966', 'foldersToFetch:[]', 'repo:{"id":179614899', 'defaultBranch:"master"', 'name:"pcc_2e"', 'ownerLogin:"ehmatthes"', 'currentUserCanPush:false', 'isFork:false', 'isEmpty:false', 'createdAt:"2019-04-05T03:41:21.000Z"', 'ownerAvatar:"https://avatars.githubusercontent.com/u/1886842?v=4"', 'public:true', 'private:false', 'isOrgOwned:false}', 'symbolsExpanded:false', 'treeExpanded:true', 'refInfo:{"name":"master"', 'listCacheKey:"v0:1670202152.719313"', 'canEdit:false', 'refType:"branch ...
